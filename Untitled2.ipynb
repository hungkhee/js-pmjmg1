# %% [markdown]
# <a href="https://colab.research.google.com/github/hungkhee/js-pmjmg1/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
import numpy as np
import math as m
import json

# %%
url = 'https://www.alphavantage.co/query?function=DIGITAL_CURRENCY_DAILY&symbol=BTC&market=THB&apikey=2Q7LP25QP24Z65UK'
r = requests.get(url)
btc = r.json()
url = 'https://www.alphavantage.co/query?function=DIGITAL_CURRENCY_DAILY&symbol=BNB&market=THB&apikey=2Q7LP25QP24Z65UK'
r = requests.get(url)
bnb = r.json()
url = 'https://www.alphavantage.co/query?function=DIGITAL_CURRENCY_DAILY&symbol=ETH&market=THB&apikey=2Q7LP25QP24Z65UK'
r = requests.get(url)
eth = r.json()
url = 'https://www.alphavantage.co/query?function=DIGITAL_CURRENCY_DAILY&symbol=DOT&market=THB&apikey=2Q7LP25QP24Z65UK'
r = requests.get(url)
dot = r.json()

# %%
btc
# Out:
# {'Meta Data': {'1. Information': 'Daily Prices and Volumes for Digital Currency',
#   '2. Digital Currency Code': 'BTC',
#   '3. Digital Currency Name': 'Bitcoin',
#   '4. Market Code': 'THB',
#   '5. Market Name': 'Thai Baht',
#   '6. Last Refreshed': '2021-09-12 00:00:00',
#   '7. Time Zone': 'UTC'},
#  'Time Series (Digital Currency Daily)': {'2021-09-12': {'1a. open (THB)': '1478082.80960000',
#    '1b. open (USD)': '45173.68000000',
#    '2a. high (THB)': '1511664.00000000',
#    '2b. high (USD)': '46200.00000000',
#    '3a. low (THB)': '1463960.20320000',
#    '3b. low (USD)': '44742.06000000',
#    '4a. close (THB)': '1503327.92560000',
#    '4b. close (USD)': '45945.23000000',
#    '5. volume': '12355.72697000',
#    '6. market cap (USD)': '12355.72697000'},
#   '2021-09-11': {'1a. open (THB)': '1467236.78400000',
#    '1b. open (USD)': '44842.20000000',
#    '2a. high (THB)': '1504725.06960000',
#    '2b. high (USD)': '45987.93000000',
# ...

# %%
btc2 = btc['Time Series (Digital Currency Daily)']

# %%
btc2 = pd.json_normalize(btc2)

# %%
days = list(btc['Time Series (Digital Currency Daily)'])
days
# Out:
# ['2021-09-12',
#  '2021-09-11',
#  '2021-09-10',
#  '2021-09-09',
#  '2021-09-08',
#  '2021-09-07',
#  '2021-09-06',
#  '2021-09-05',
#  '2021-09-04',
#  '2021-09-03',
#  '2021-09-02',
#  '2021-09-01',
#  '2021-08-31',
#  '2021-08-30',
#  '2021-08-29',
#  '2021-08-28',
#  '2021-08-27',
#  '2021-08-26',
#  '2021-08-25',
#  '2021-08-24',
#  '2021-08-23',
#  '2021-08-22',
#  '2021-08-21',
#  '2021-08-20',
#  '2021-08-19',
#  '2021-08-18',
#  '2021-08-17',
#  '2021-08-16',
#  '2021-08-15',
#  '2021-08-14',
#  '2021-08-13',
#  '2021-08-12',
#  '2021-08-11',
#  '2021-08-10',
#  '2021-08-09',
#  '2021-08-08',
#  '2021-08-07',
#  '2021-08-06',
#  '2021-08-05',
#  '2021-08-04',
#  '2021-08-03',
#  '2021-08-02',
#  '2021-08-01',
#  '2021-07-31',
#  '2021-07-30',
#  '2021-07-29',
#  '2021-07-28',
#  '2021-07-27',
#  '2021-07-26',
#  '2021-07-25',
#  '2021-07-24',
#  '2021-07-23',
#  '2021-07-22',
#  '2021-07-21',
#  '2021-07-20',
#  '2021-07-19',
#  '2021-07-18',
#  '2021-07-17',
# ...

# %%
df_btc = pd.DataFrame()

# %%
for i in days:
  print(btc2[i])
  #time = pd.json_normalize(btc2[i])
  #df_btc = df_btc.append(time,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2021-09-12'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-de21bbf53851> in <module>()
#       1 for i in days:
# ...

# %%
df_btc.insert(0,"day",days)

# %%
df_btc.drop('6. market cap (USD)',axis='columns', inplace=True)

# %%
df_btc.head(365)
# Out:
#             day    1a. open (THB)  ... 4b. close (USD)       5. volume
# 0    2021-09-12  1478082.80960000  ...  45945.23000000  12355.72697000
# 1    2021-09-11  1467236.78400000  ...  45173.69000000  30440.40810000
# 2    2021-09-10  1518048.98080000  ...  44850.91000000  49048.26618000
# 3    2021-09-09  1506700.70320000  ...  46395.14000000  50651.66002000
# 4    2021-09-08  1533539.61040000  ...  46048.31000000  65069.31520000
# ..          ...               ...  ...             ...             ...
# 360  2020-09-17   358415.20720000  ...  10939.99000000  55601.61452900
# 361  2020-09-16   352892.72560000  ...  10954.01000000  64991.51244000
# 362  2020-09-15   349180.31440000  ...  10785.31000000  61822.45278600
# 363  2020-09-14   338090.52480000  ...  10671.77000000  67059.29136100
# 364  2020-09-13   341618.72240000  ...  10332.83000000  43837.60986500
#
# [365 rows x 10 columns]

# %%
df_btc.rename(columns={"1a. open (THB)": "open (THB)", "1b. open (USD)": "open (USD)","2a. high (THB)":"high (THB)","2b. high (USD)":"high (USD)","3a. low (THB)":"low (THB)","3b. low (USD)":"low (USD)","4a. close (THB)":"close (THB)","4b. close (USD)":"close (USD)","5. volume":"volume"})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-81a93f25a864> in <module>()
# ----> 1 df_btc.rename(columns={"1a. open (THB)": "open (THB)", "1b. open (USD)": "open (USD)","2a. high (THB)":"high (THB)","2b. high (USD)":"high (USD)","3a. low (THB)":"low (THB)","3b. low (USD)":"low (USD)","4a. close (THB)":"close (THB)","4b. close (USD)":"close (USD)","5. volume":"volume"})
#
# NameError: name 'df_btc' is not defined
